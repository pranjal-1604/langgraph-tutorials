# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content:str

# %%
def create_outline(state:BlogState)->BlogState:
    title = state['title']
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content
    state['outline'] = outline
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title  = state['title']
    outline = state['outline']
    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'
    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
initial_state = {'title':'Rise of AI in India'}
final_state = workflow.invoke(initial_state)
print(final_state['content'])
# Out:
# **The Rise of AI in India: A New Era of Innovation and Growth**
#
# **Introduction**
#
# Artificial Intelligence (AI) has been transforming the world, and India is no exception. The growing importance of AI globally has made it a crucial component of India's economic growth and development. As a country with a large and diverse population, India has the potential to leverage AI to drive innovation, improve healthcare, enhance education, and boost economic growth. In this blog, we will explore the rise of AI in India, driven by government initiatives, technological advancements, and increasing demand for AI-powered solutions. India is witnessing a significant rise in AI adoption, and this trend is expected to continue in the coming years.
#
# **Current State of AI in India**
#
# India's AI landscape is rapidly evolving, with key players, startups, and research institutions driving innovation and growth. The current AI ecosystem in India is characterized by a mix of challenges and opportunities. According to a recent report, there are over 500 AI startups in India, with many more in the pipeline. These startups have received significant funding, with investments totaling over $1 billion in the past year alone. AI adoption rates are also increasing across various industries, including healthcare, finance, and manufacturing. For example, the healthcare sector has seen a significant adoption of AI-powered diagnosis and telemedicine, while the finance sector has leveraged AI for fraud detection and credit scoring.
#
# Some key statistics and trends in India's AI landscape include:
#
# * The number of AI startups in India has grown by over 50% in the past year.
# * AI startups in India have received over $1 billion in funding in the past year.
# * AI adoption rates in the healthcare sector have increased by over 20% in the past year.
# * The finance sector has seen a significant increase in AI adoption, with over 50% of banks and financial institutions using AI-powered solutions.
#
# **Government Initiatives and Policies**
#
# The Indian government has been actively promoting AI adoption through various initiatives and policies. The National AI Strategy, launched in 2018, aims to make India a leader in AI by 2025. The AI Task Force, set up by the government, has been working to develop a comprehensive AI policy framework for the country. The government has also launched several AI-related policies and regulations, including the Data Protection Bill and the National Digital Communications Policy. These initiatives have had a significant impact on the growth of AI in India, with many startups and companies leveraging government funding and support to develop AI-powered solutions.
#
# Some examples of successful government-led AI projects in India include:
#
# * The Indian Railways' AI-powered predictive maintenance system, which has reduced maintenance costs by over 20%.
# * The Indian government's AI-powered chatbot, which provides citizens with information and services.
# * The AI-powered healthcare platform launched by the Indian government, which provides citizens with access to telemedicine and other healthcare services.
#
# **Key Industries Driving AI Adoption in India**
#
# Several industries are driving AI adoption in India, including healthcare, finance, and manufacturing. In the healthcare sector, AI is being used for diagnosis, telemedicine, and personalized medicine. For example, AI-powered diagnostic systems are being used to detect diseases such as cancer and diabetes. In the finance sector, AI is being used for fraud detection, credit scoring, and portfolio management. For example, AI-powered credit scoring systems are being used to provide credit to small businesses and individuals.
#
# Some examples of companies and startups in these industries that are leveraging AI for innovation and growth include:
#
# * Healthcare: AI-powered diagnostic systems developed by startups such as Niramai and SigTuple.
# * Finance: AI-powered credit scoring systems developed by companies such as CreditVidya and Loanbazaar.
# * Manufacturing: AI-powered predictive maintenance systems developed by companies such as Tata Motors and Mahindra & Mahindra.
#
# **Opportunities and Challenges**
#
# India's AI ecosystem presents several opportunities and challenges. The country has a large talent pool, with many skilled professionals in AI and related fields. The cost advantage of developing AI solutions in India is also significant, with many companies leveraging Indian talent to develop AI-powered solutions. However, there are also several challenges, including data quality, infrastructure, and regulatory frameworks. For example, the lack of high-quality data is a significant challenge for many AI startups in India.
#
# Some examples of how companies and startups are addressing these challenges and leveraging opportunities include:
#
# * Developing AI-powered solutions that can work with low-quality data.
# * Partnering with government agencies to develop AI-powered solutions for social impact.
# * Leveraging India's talent pool to develop AI-powered solutions for global markets.
#
# **Future Outlook and Predictions**
#
# The future outlook for AI in India is promising, with predicted growth rates and investment in AI expected to increase significantly. Emerging trends and technologies, such as edge AI and explainable AI, are also expected to play a significant role in India's AI ecosystem. According to a recent report, the Indian AI market is expected to grow to over $7 billion by 2025, with a compound annual growth rate (CAGR) of over 30%.
#
# Some examples of how India can leverage AI to drive economic growth, improve healthcare, and enhance education include:
#
# * Developing AI-powered solutions for agriculture, such as precision farming and crop monitoring.
# * Leveraging AI to improve healthcare outcomes, such as disease diagnosis and personalized medicine.
# * Developing AI-powered educational platforms, such as adaptive learning systems and virtual classrooms.
#
# **Conclusion**
#
# In conclusion, the rise of AI in India is a significant trend that is expected to continue in the coming years. With government initiatives, technological advancements, and increasing demand for AI-powered solutions driving growth, India is poised to become a leader in AI. However, there are also several challenges that need to be addressed, including data quality, infrastructure, and regulatory frameworks. To drive growth and innovation in India, it is essential to invest in AI education, research, and development. We encourage businesses, governments, and individuals to take advantage of the opportunities presented by AI and work together to create a future where AI drives economic growth, improves healthcare, and enhances education in India.
